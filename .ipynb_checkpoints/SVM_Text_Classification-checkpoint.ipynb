# %% [markdown]
# ## Nabila Hannania
# ## 13519097
# ## Text Classification with SVM and Vector Space Model

# %%
import sys
# !{sys.executable} -m pip install library
# Out:
# Requirement already satisfied: library in d:\aplikasi\anaconda\lib\site-packages (0.0.0)

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
df_labels = pd.read_csv('data_worthcheck/labels.txt', sep=" ", header=None)
df_labels_labels = list(df_labels[0])
df_labels_labels
# Out:
# ['no', 'yes']

# %% [markdown]
# ## Read data

# %%
train_data = pd.read_csv('data_worthcheck/train.csv')
train_data
# Out:
#        Unnamed: 0                                             text_a label
# 0               0  betewe buka twitter cuman ngetweet liat home b...    no
# 1               1  mas piyuuu mugo2 corona tuh mulut tersumpal ma...    no
# 2               2  e100ss gini buka informasi sejelas nya identit...   yes
# 3               3  neng solo wes ono terduga corona cobo neng ati...    no
# 4               4  midiahn nii akun gak takut takut nya isu coron...    no
# ...           ...                                                ...   ...
# 21596       21596  depok panas ga karuan kereta sampe pasming huj...    no
# 21597       21597  oxfara arie kriting yg lebi goblo nya orang ke...    no
# 21598       21598  virus corona menyaba depok cuci tangan makan n...    no
# 21599       21599  mata sipit tinggal depok udah abis dah bahan c...    no
# 21600       21600       i ak batuk pilek pusing demam anjir ak depok    no
#
# [21601 rows x 3 columns]

# %%
# persebaran data training
sns.countplot(train_data.label)
plt.xlabel('Label')
plt.title('Training Data')
# Out:
# Text(0.5, 1.0, 'Training Data')

# %%
dev_data = pd.read_csv('data_worthcheck/dev.csv')
dev_data
# Out:
#                                                  text_a label
# 0                               jek dajal ga depok bang    no
# 1     detikcom untung depok masuk wilayah nya ridwan...    no
# 2     df dom jakarta depok yg gunain vc cabang nya c...    no
# 3                                     your2rl depok jkt    no
# 4     doakan indonesia selamat virus corona pkb depo...   yes
# ...                                                 ...   ...
# 2795  ku tenang2 bae ku sih ya corona nya ga depok k...    no
# 2796  guru hati hati ya virus corona uda indonesia t...   yes
# 2797  4 terawan menyebut virus corona indonesia terd...   yes
# 2798        realffk buhari can t pronounce corona virus    no
# 2799  hadapi wabah corona pemuda muhammadiyah pemeri...   yes
#
# [2800 rows x 2 columns]

# %%
# persebaran data validation (dev)
sns.countplot(dev_data.label)
plt.xlabel('Label')
plt.title('Validation (dev) Data')
# Out:
# Text(0.5, 1.0, 'Validation (dev) Data')

# %%
test_data = pd.read_csv('data_worthcheck/test.csv')
test_data
# Out:
#                                                  text_a label
# 0                               jek dajal ga depok bang    no
# 1     detikcom untung depok masuk wilayah nya ridwan...    no
# 2     df dom jakarta depok yg gunain vc cabang nya c...    no
# 3                                     your2rl depok jkt    no
# 4     doakan indonesia selamat virus corona pkb depo...   yes
# ...                                                 ...   ...
# 2795  ku tenang2 bae ku sih ya corona nya ga depok k...    no
# 2796  guru hati hati ya virus corona uda indonesia t...   yes
# 2797  4 terawan menyebut virus corona indonesia terd...   yes
# 2798        realffk buhari can t pronounce corona virus    no
# 2799  hadapi wabah corona pemuda muhammadiyah pemeri...   yes
#
# [2800 rows x 2 columns]

# %%
# persebaran data testing
sns.countplot(test_data.label)
plt.xlabel('Label')
plt.title('Testing Data')
# Out:
# Text(0.5, 1.0, 'Testing Data')

# %% [markdown]
# ## Preprocessing Data

# %%
# 1. Removing Blank Spaces
train_data['text_a'].dropna(inplace=True)
dev_data['text_a'].dropna(inplace=True)
test_data['text_a'].dropna(inplace=True)

# 2. Changing all text to lowercase
train_data['text_original'] = train_data['text_a']
train_data['text_a'] = [entry.lower() for entry in train_data['text_a']]

dev_data['text_original'] = dev_data['text_a']
dev_data['text_a'] = [entry.lower() for entry in dev_data['text_a']]

test_data['text_original'] = test_data['text_a']
test_data['text_a'] = [entry.lower() for entry in test_data['text_a']]


# 3. Tokenization
# each entry in the dataset corpus will be broken into set of words
train_data['text_a']= [word_tokenize(entry) for entry in train_data['text_a']]
dev_data['text_a']= [word_tokenize(entry) for entry in dev_data['text_a']]
test_data['text_a']= [word_tokenize(entry) for entry in test_data['text_a']]

# %%
# 4. Remove Stop words and Non-alphabet word
stop_words = set(stopwords.words('indonesian'))

# remove stopword and Non-alphabet word in train data
for index, entry in enumerate (train_data['text_a']):
    Final_words = []
    for word in entry:
        # Below condition is to check for Stop words and consider only alphabets
        # jika hanya terdapat alfabet pada kata
        if word.isalpha() :
            if word not in stop_words :
                Final_words.append(word)
        
          # jika terdapat bukan alfabet pada kata
        else :
            # check apakah kata tersebut merupakan pengulangan kata
            if word[-1] == "2":
                if word[:-1] not in stop_words:
                    Final_words.append(word[:-1])
    # The final processed set of words for each iteration will be stored in 'text_final'
    train_data.loc[index, 'text_final'] = str(Final_words)

# remove stopword and Non-alphabet word in dev data
for index, entry in enumerate (dev_data['text_a']):
    Final_words = []
    for word in entry:
        # Below condition is to check for Stop words and consider only alphabets
        # jika hanya terdapat alfabet pada kata
        if word.isalpha() :
            if word not in stop_words :
                Final_words.append(word)
        
          # jika terdapat bukan alfabet pada kata
        else :
            # check apakah kata tersebut merupakan pengulangan kata
            if word[-1] == "2":
                if word[:-1] not in stop_words:
                    Final_words.append(word[:-1])
            
    # The final processed set of words for each iteration will be stored in 'text_final'
    dev_data.loc[index, 'text_final'] = str(Final_words)

# remove stopword and Non-alphabet word in test data
for index, entry in enumerate (test_data['text_a']):
    Final_words = []
    for word in entry:
        # Below condition is to check for Stop words and consider only alphabets
        # jika hanya terdapat alfabet pada kata
        if word.isalpha() :
            if word not in stop_words :
                Final_words.append(word)
        
          # jika terdapat bukan alfabet pada kata
        else :
            # check apakah kata tersebut merupakan pengulangan kata
            if word[-1] == "2":
                if word[:-1] not in stop_words:
                    Final_words.append(word[:-1])

    # The final processed set of words for each iteration will be stored in 'text_final'
    test_data.loc[index, 'text_final'] = str(Final_words)

# %%
train_data
# Out:
#        Unnamed: 0                                             text_a label  \
# 0               0  [betewe, buka, twitter, cuman, ngetweet, liat,...    no
# 1               1  [mas, piyuuu, mugo2, corona, tuh, mulut, tersu...    no
# 2               2  [e100ss, gini, buka, informasi, sejelas, nya, ...   yes
# 3               3  [neng, solo, wes, ono, terduga, corona, cobo, ...    no
# 4               4  [midiahn, nii, akun, gak, takut, takut, nya, i...    no
# ...           ...                                                ...   ...
# 21596       21596  [depok, panas, ga, karuan, kereta, sampe, pasm...    no
# 21597       21597  [oxfara, arie, kriting, yg, lebi, goblo, nya, ...    no
# 21598       21598  [virus, corona, menyaba, depok, cuci, tangan, ...    no
# 21599       21599  [mata, sipit, tinggal, depok, udah, abis, dah,...    no
# 21600       21600  [i, ak, batuk, pilek, pusing, demam, anjir, ak...    no
#
#                                            text_original  \
# 0      betewe buka twitter cuman ngetweet liat home b...
# 1      mas piyuuu mugo2 corona tuh mulut tersumpal ma...
# 2      e100ss gini buka informasi sejelas nya identit...
# 3      neng solo wes ono terduga corona cobo neng ati...
# 4      midiahn nii akun gak takut takut nya isu coron...
# ...                                                  ...
# 21596  depok panas ga karuan kereta sampe pasming huj...
# 21597  oxfara arie kriting yg lebi goblo nya orang ke...
# 21598  virus corona menyaba depok cuci tangan makan n...
# 21599  mata sipit tinggal depok udah abis dah bahan c...
# 21600       i ak batuk pilek pusing demam anjir ak depok
#
#                                               text_final
# 0      ['betewe', 'buka', 'twitter', 'cuman', 'ngetwe...
# 1      ['mas', 'piyuuu', 'mugo', 'corona', 'tuh', 'mu...
# 2      ['gini', 'buka', 'informasi', 'sejelas', 'nya'...
# 3      ['neng', 'solo', 'wes', 'ono', 'terduga', 'cor...
# 4      ['midiahn', 'nii', 'akun', 'gak', 'takut', 'ta...
# ...                                                  ...
# 21596  ['depok', 'panas', 'ga', 'karuan', 'kereta', '...
# 21597  ['oxfara', 'arie', 'kriting', 'yg', 'lebi', 'g...
# 21598  ['virus', 'corona', 'menyaba', 'depok', 'cuci'...
# 21599  ['mata', 'sipit', 'tinggal', 'depok', 'udah', ...
# 21600  ['i', 'ak', 'batuk', 'pilek', 'pusing', 'demam...
#
# [21601 rows x 5 columns]

# %%
dev_data
# Out:
#                                                  text_a label  \
# 0                         [jek, dajal, ga, depok, bang]    no
# 1     [detikcom, untung, depok, masuk, wilayah, nya,...    no
# 2     [df, dom, jakarta, depok, yg, gunain, vc, caba...    no
# 3                                 [your2rl, depok, jkt]    no
# 4     [doakan, indonesia, selamat, virus, corona, pk...   yes
# ...                                                 ...   ...
# 2795  [ku, tenang2, bae, ku, sih, ya, corona, nya, g...    no
# 2796  [guru, hati, hati, ya, virus, corona, uda, ind...   yes
# 2797  [4, terawan, menyebut, virus, corona, indonesi...   yes
# 2798  [realffk, buhari, can, t, pronounce, corona, v...    no
# 2799  [hadapi, wabah, corona, pemuda, muhammadiyah, ...   yes
#
#                                           text_original  \
# 0                               jek dajal ga depok bang
# 1     detikcom untung depok masuk wilayah nya ridwan...
# 2     df dom jakarta depok yg gunain vc cabang nya c...
# 3                                     your2rl depok jkt
# 4     doakan indonesia selamat virus corona pkb depo...
# ...                                                 ...
# 2795  ku tenang2 bae ku sih ya corona nya ga depok k...
# 2796  guru hati hati ya virus corona uda indonesia t...
# 2797  4 terawan menyebut virus corona indonesia terd...
# 2798        realffk buhari can t pronounce corona virus
# 2799  hadapi wabah corona pemuda muhammadiyah pemeri...
#
#                                              text_final
# 0               ['jek', 'dajal', 'ga', 'depok', 'bang']
# 1     ['detikcom', 'untung', 'depok', 'masuk', 'wila...
# 2     ['df', 'dom', 'jakarta', 'depok', 'yg', 'gunai...
# 3                                      ['depok', 'jkt']
# 4     ['doakan', 'indonesia', 'selamat', 'virus', 'c...
# ...                                                 ...
# 2795  ['ku', 'tenang', 'bae', 'ku', 'sih', 'ya', 'co...
# 2796  ['guru', 'hati', 'hati', 'ya', 'virus', 'coron...
# 2797  ['terawan', 'menyebut', 'virus', 'corona', 'in...
# 2798  ['realffk', 'buhari', 'can', 't', 'pronounce',...
# 2799  ['hadapi', 'wabah', 'corona', 'pemuda', 'muham...
#
# [2800 rows x 4 columns]

# %%
test_data
# Out:
#                                                  text_a label  \
# 0                         [jek, dajal, ga, depok, bang]    no
# 1     [detikcom, untung, depok, masuk, wilayah, nya,...    no
# 2     [df, dom, jakarta, depok, yg, gunain, vc, caba...    no
# 3                                 [your2rl, depok, jkt]    no
# 4     [doakan, indonesia, selamat, virus, corona, pk...   yes
# ...                                                 ...   ...
# 2795  [ku, tenang2, bae, ku, sih, ya, corona, nya, g...    no
# 2796  [guru, hati, hati, ya, virus, corona, uda, ind...   yes
# 2797  [4, terawan, menyebut, virus, corona, indonesi...   yes
# 2798  [realffk, buhari, can, t, pronounce, corona, v...    no
# 2799  [hadapi, wabah, corona, pemuda, muhammadiyah, ...   yes
#
#                                           text_original  \
# 0                               jek dajal ga depok bang
# 1     detikcom untung depok masuk wilayah nya ridwan...
# 2     df dom jakarta depok yg gunain vc cabang nya c...
# 3                                     your2rl depok jkt
# 4     doakan indonesia selamat virus corona pkb depo...
# ...                                                 ...
# 2795  ku tenang2 bae ku sih ya corona nya ga depok k...
# 2796  guru hati hati ya virus corona uda indonesia t...
# 2797  4 terawan menyebut virus corona indonesia terd...
# 2798        realffk buhari can t pronounce corona virus
# 2799  hadapi wabah corona pemuda muhammadiyah pemeri...
#
#                                              text_final
# 0               ['jek', 'dajal', 'ga', 'depok', 'bang']
# 1     ['detikcom', 'untung', 'depok', 'masuk', 'wila...
# 2     ['df', 'dom', 'jakarta', 'depok', 'yg', 'gunai...
# 3                                      ['depok', 'jkt']
# 4     ['doakan', 'indonesia', 'selamat', 'virus', 'c...
# ...                                                 ...
# 2795  ['ku', 'tenang', 'bae', 'ku', 'sih', 'ya', 'co...
# 2796  ['guru', 'hati', 'hati', 'ya', 'virus', 'coron...
# 2797  ['terawan', 'menyebut', 'virus', 'corona', 'in...
# 2798  ['realffk', 'buhari', 'can', 't', 'pronounce',...
# 2799  ['hadapi', 'wabah', 'corona', 'pemuda', 'muham...
#
# [2800 rows x 4 columns]

# %% [markdown]
# ## Split Data

# %%
# split data to X dan Y
Train_X = train_data['text_final']
Train_Y = train_data['label']

Dev_X = dev_data['text_final']
Dev_Y = dev_data['label']

Test_X = test_data['text_final']
Test_Y = test_data['label']

# %%
print("Train_X : \n", Train_X)
print("Train_Y : \n", Train_Y)
print("Dev_X : \n", Dev_X)
print("Dev_Y : \n", Dev_Y)
print("Test_X : \n", Test_X)
print("Test_Y : \n", Test_Y)
# Out:
# Train_X :
#  0        ['betewe', 'buka', 'twitter', 'cuman', 'ngetwe...
# 1        ['mas', 'piyuuu', 'mugo', 'corona', 'tuh', 'mu...
# 2        ['gini', 'buka', 'informasi', 'sejelas', 'nya'...
# 3        ['neng', 'solo', 'wes', 'ono', 'terduga', 'cor...
# 4        ['midiahn', 'nii', 'akun', 'gak', 'takut', 'ta...
#                                ...
# 21596    ['depok', 'panas', 'ga', 'karuan', 'kereta', '...
# 21597    ['oxfara', 'arie', 'kriting', 'yg', 'lebi', 'g...
# 21598    ['virus', 'corona', 'menyaba', 'depok', 'cuci'...
# 21599    ['mata', 'sipit', 'tinggal', 'depok', 'udah', ...
# 21600    ['i', 'ak', 'batuk', 'pilek', 'pusing', 'demam...
# Name: text_final, Length: 21601, dtype: object
# Train_Y :
#  0         no
# 1         no
# 2        yes
# 3         no
# 4         no
#         ...
# 21596     no
# 21597     no
# 21598     no
# 21599     no
# 21600     no
# Name: label, Length: 21601, dtype: object
# Dev_X :
#  0                 ['jek', 'dajal', 'ga', 'depok', 'bang']
# 1       ['detikcom', 'untung', 'depok', 'masuk', 'wila...
# 2       ['df', 'dom', 'jakarta', 'depok', 'yg', 'gunai...
# 3                                        ['depok', 'jkt']
# 4       ['doakan', 'indonesia', 'selamat', 'virus', 'c...
#                               ...
# 2795    ['ku', 'tenang', 'bae', 'ku', 'sih', 'ya', 'co...
# 2796    ['guru', 'hati', 'hati', 'ya', 'virus', 'coron...
# 2797    ['terawan', 'menyebut', 'virus', 'corona', 'in...
# 2798    ['realffk', 'buhari', 'can', 't', 'pronounce',...
# 2799    ['hadapi', 'wabah', 'corona', 'pemuda', 'muham...
# Name: text_final, Length: 2800, dtype: object
# Dev_Y :
#  0        no
# 1        no
# 2        no
# 3        no
# 4       yes
#        ...
# 2795     no
# 2796    yes
# 2797    yes
# 2798     no
# 2799    yes
# Name: label, Length: 2800, dtype: object
# Test_X :
#  0                 ['jek', 'dajal', 'ga', 'depok', 'bang']
# 1       ['detikcom', 'untung', 'depok', 'masuk', 'wila...
# 2       ['df', 'dom', 'jakarta', 'depok', 'yg', 'gunai...
# 3                                        ['depok', 'jkt']
# 4       ['doakan', 'indonesia', 'selamat', 'virus', 'c...
#                               ...
# 2795    ['ku', 'tenang', 'bae', 'ku', 'sih', 'ya', 'co...
# 2796    ['guru', 'hati', 'hati', 'ya', 'virus', 'coron...
# 2797    ['terawan', 'menyebut', 'virus', 'corona', 'in...
# 2798    ['realffk', 'buhari', 'can', 't', 'pronounce',...
# 2799    ['hadapi', 'wabah', 'corona', 'pemuda', 'muham...
# Name: text_final, Length: 2800, dtype: object
# Test_Y :
#  0        no
# 1        no
# 2        no
# 3        no
# 4       yes
#        ...
# 2795     no
# 2796    yes
# 2797    yes
# 2798     no
# 2799    yes
# Name: label, Length: 2800, dtype: object

# %% [markdown]
# ## Transform Label from Categorical to Numerical

# %%
# Transformasi data kategorikal menjadi numerikal : dengan menggunakan labelEncoder
# untuk label yang bernilai "no" akan diubah menjadi 0
# untuk label yang bernilai "yesy" akan diubah menjadi 1
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Dev_Y = Encoder.fit_transform(Dev_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
print("Train_Y : \n", Train_Y)
print("Dev_Y : \n", Dev_Y)
print("Test_Y : \n", Test_Y)
# Out:
# Train_Y :
#  [0 0 1 ... 0 0 0]
# Dev_Y :
#  [0 0 0 ... 1 0 1]
# Test_Y :
#  [0 0 0 ... 1 0 1]

# %% [markdown]
# ## Feature Extraction
# Fitur yang penting pada dataset akan direpresentasikan dalam bentuk matrix TF-IDF (Term Frequency-Inverse Document Frequency). TF-IDF sendiri  dapat mengukur relevansi suatu kata dalam dokumen di antara kumpulan dokumen

# %%
Tfidf_vect = TfidfVectorizer()

# vocabulary-nya harus menggunakan semua kata pada dataset, namun karena dataset test dan dev berisi data yang sama maka hanya akan digunakan data train dan dev untuk membuat vocabulary pada TD-IDF vector
corpus = [*Train_X, *Dev_X]
Tfidf_vect.fit(corpus)

print(Tfidf_vect.vocabulary_)
# Out:
# {'betewe': 4518, 'buka': 5664, 'twitter': 39686, 'cuman': 7339, 'ngetweet': 26784, 'liat': 21219, 'home': 14513, 'berita': 4006, 'corona': 7101, 'panik': 28599, 'kepikiran': 18796, 'ndamau': 26164, 'yg': 42147, 'aware': 2437, 'aja': 695, 'll': 21412, 'stay': 36439, 'at': 2241, 'nda': 26151, 'rumah': 33320, 'kalo': 17549, 'banget': 3002, 'mas': 22501, 'piyuuu': 30564, 'mugo': 25452, 'tuh': 39426, 'mulut': 25549, 'tersumpal': 38369, 'ma': 21745, 'gini': 12907, 'informasi': 15578, 'sejelas': 34421, 'nya': 27520, 'identitas': 14978, 'daerah': 7467, 'penderita': 29453, 'terjangkit': 38183, 'infokan': 15550, 'masyarakat': 22636, 'mengisolasi': 23934, 'kontak': 19930, 'langsung': 20802, 'positif': 31018, 'ditutup': 9875, 'tutupi': 39637, 'neng': 26308, 'solo': 36091, 'wes': 41352, 'ono': 28023, 'terduga': 38102, 'cobo': 6880, 'ati': 2277, 'mu': 25387, 'conora': 7010, 'midiahn': 24617, 'nii': 27015, 'akun': 890, 'gak': 12274, 'takut': 37334, 'isu': 16036, 'wkwkwkw': 41567, 'hey': 14217, 'prrgi': 31498, 'sna': 35958, 'gara': 12445, 'masuk': 22621, 'ketempat': 19065, 'mesti': 24505, 'scan': 34100, 'jidat': 16816, 'gw': 13408, 'kek': 18391, 'jajanan': 16320, 'indomaret': 15419, 'jokowi': 17047, 'menteri': 24153, 'silakan': 35498, 'tes': 38423, 'pencegahan': 29419, 'other': 28198, 'moms': 25126, 'minum': 24781, 'multivitamin': 25544, 'my': 25741, 'mom': 25114, 'rebusan': 32457, 'sambiloto': 33724, 'mamaciaaa': 22143, 'mnrut': 25021, 'gue': 13292, 'jngan': 16968, 'dkt': 9993, 'cb': 6174, 'puspa': 31748, 'jaya': 16587, 'damri': 7584, 'als': 1125, 'tran': 39154, 'jakarta': 16330, 'aj': 694, 'komachiyama': 19749, 'tiati': 38680, 'kemenkesri': 18603, 'mohon': 25096, 'transparan': 39172, 'mudah': 25420, 'spt': 36318, 'utk': 40381, 'data': 7718, 'iya': 16150, 'gua': 13254, 'tau': 37604, 'ga': 12164, 'parno': 28729, 'gitu': 12939, 'kont': 19929, 'prosedur': 31445, 'tp': 39104, 'gk': 12959, 'lebay': 20994, 'bikin': 4742, 'risih': 32978, 'gilang': 12882, 'mahesa': 21916, 'bogor': 5147, 'blum': 5037, 'imajinarii': 15223, 'iyaaa': 16152, 'kehitung': 18337, 'angett': 1499, 'obat': 27749, 'teler': 37809, 'gabisa': 12185, 'bobo': 5110, 'dibawelin': 8374, 'sedih': 34303, 'emang': 10888, 'amiinn': 1288, 'makasih': 22010, 'ya': 41886, 'amit': 1309, 'kena': 18663, 'momen': 25116, 'dipakai': 9179, 'pencitraan': 29429, 'semoga': 34708, 'masif': 22544, 'penyebaran': 29805, 'kapok': 17733, 'rlt': 33045, 'mikirin': 24651, 'ortu': 28162, 'ku': 20295, 'meninggal': 24041, 'mekkah': 22992, 'karna': 17833, 'bentar': 3702, 'berangkat': 3753, 'umroh': 40007, 'sengaja': 34771, 'makan': 21993, 'dikasih': 8812, 'virus': 40692, 'sumpah': 36823, 'gatau': 12507, 'bereaksi': 3894, 'kayak': 18011, 'udh': 39798, 'dmn': 10020, 'kl': 19542, 'emg': 10908, 'mo': 25036, 'begimana': 3517, 'lg': 21182, 'jateng': 16525, 'jatim': 16534, 'siaga': 35353, 'info': 15524, 'disebar': 9496, 'jabar': 16204, 'silent': 35508, 'yak': 41947, 'kabar': 17328, 'pisan': 30535, 'prediksi': 31213, 'pola': 30802, 'amp': 1331, 'sejarah': 34414, 'perjalanan': 30026, 'orang': 28112, 'indo': 15413, 'singapura': 35598, 'clear': 6810, 'malaysia': 22095, 'undertesting': 40076, 'indonesia': 15430, 'angka': 1525, 'terinfeksi': 38162, 'rendah': 32648, 'probabilitas': 31354, 'dll': 10003, 'dst': 10342, 'back': 2677, 'of': 27816, 'the': 38541, 'hand': 13728, 'calculation': 5976, 'time': 38750, 'will': 41464, 'tell': 37821, 'sebener': 34227, 'dr': 10248, 'sih': 35442, 'kesadaran': 18923, 'masi': 22540, 'egois': 10691, 'pemerintah': 29295, 'kebijakan': 18160, 'warga': 41125, 'jaga': 16269, 'tindakan': 38770, 'preventif': 31275, 'guys': 13403, 'malem': 22104, 'minggu': 24734, 'main': 21946, 'mall': 22119, 'pagi': 28357, 'covid': 7194, 'senin': 34782, 'isolasi': 16000, 'selasa': 34551, 'mati': 22681, 'untung': 40164, 'rebahan': 32447, 'dirumah': 9420, 'aje': 719, 'prabndriapsari': 31121, 'penulara': 29758, 'cepat': 6292, 'odikcontinental': 27800, 'elisa': 10841, 'jkt': 16929, 'jabarprovgoid': 16211, 'humasjabar': 14730,  ...

# %%
# tranformasi data ke dalam bentuk representasi Tf-IDF
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Dev_X_Tfidf = Tfidf_vect.transform(Dev_X)
Test_X_Tfidf = Tfidf_vect.transform(Dev_X)

print("Train_X_Tfidf : \n", Train_X_Tfidf)
print("Dev_X_Tfidf : \n", Dev_X_Tfidf)
print("Test_X_Tfidf : \n", Test_X_Tfidf)
# Out:
# Train_X_Tfidf :
#    (0, 42147)	0.07211954073346036
#   (0, 39686)	0.16378506159701625
#   (0, 36439)	0.1462903374367259
#   (0, 33320)	0.11310626595727696
#   (0, 28599)	0.1273326118967822
#   (0, 26784)	0.2231565067925994
#   (0, 26164)	0.24380629869675807
#   (0, 26151)	0.4091642511195389
#   (0, 21412)	0.22691336681684499
#   (0, 21219)	0.13858328886588164
#   (0, 18796)	0.18463879903482613
#   (0, 17549)	0.10201128621859722
#   (0, 14513)	0.5136176218408303
#   (0, 7339)	0.16440209073256268
#   (0, 7101)	0.04845659214836899
#   (0, 5664)	0.27222638370250907
#   (0, 4518)	0.24380629869675807
#   (0, 4006)	0.11931833394292257
#   (0, 3002)	0.12251658353516692
#   (0, 2437)	0.18689006146257497
#   (0, 2241)	0.16288785540815373
#   (0, 695)	0.09100458384530037
#   (1, 39426)	0.26676354916607853
#   (1, 38369)	0.4943193819473392
#   (1, 30564)	0.34310185010865596
#   :	:
#   (21598, 4673)	0.20522802326974626
#   (21598, 3421)	0.27613288496071237
#   (21599, 39781)	0.1440066468878215
#   (21599, 39010)	0.25431476396788505
#   (21599, 38777)	0.19450353106585047
#   (21599, 35641)	0.33836274005123324
#   (21599, 22649)	0.20695904695267525
#   (21599, 8870)	0.4580828740568264
#   (21599, 8799)	0.32108488383369344
#   (21599, 8013)	0.10760059204777106
#   (21599, 7495)	0.17320980795043248
#   (21599, 7101)	0.06724971988217639
#   (21599, 6861)	0.09308964822857087
#   (21599, 6271)	0.33836274005123324
#   (21599, 3046)	0.33836274005123324
#   (21599, 2773)	0.22994344765047722
#   (21599, 1331)	0.16445422897600748
#   (21599, 213)	0.20695904695267525
#   (21600, 31742)	0.343170054594522
#   (21600, 30447)	0.39995903536566396
#   (21600, 8013)	0.1538682896667557
#   (21600, 7930)	0.3610537117692583
#   (21600, 3301)	0.3132965069966974
#   (21600, 1592)	0.32326656068561666
#   (21600, 751)	0.6046287123167324
# Dev_X_Tfidf :
#    (0, 16663)	0.561419550581454
#   (0, 12164)	0.23805145594059293
#   (0, 8013)	0.2005587152148625
#   (0, 7519)	0.6562426712978519
#   (0, 2992)	0.396561912781227
#   (1, 41455)	0.4027916525226427
#   (1, 40164)	0.23300720750281068
#   (1, 32899)	0.26970431062417133
#   (1, 27520)	0.18581620535155244
#   (1, 22621)	0.3205359439762914
#   (1, 21583)	0.1870876037772382
#   (1, 19730)	0.31519375614915374
#   (1, 17600)	0.26826354021437054
#   (1, 17549)	0.141698662021964
#   (1, 8093)	0.19734335316448876
#   (1, 8013)	0.10769476058637062
#   (1, 5861)	0.24623920265677976
#   (1, 5732)	0.2799374234375938
#   (1, 1566)	0.26427623170916753
#   (1, 1166)	0.21159442454849317
#   (1, 213)	0.20714017077951108
#   (2, 42147)	0.18303271606662344
#   (2, 40509)	0.2790456678934911
#   (2, 38069)	0.30937890473777135
#   (2, 35308)	0.3219183647085779
#   :	:
#   (2797, 29295)	0.20427037866459188
#   (2797, 29289)	0.3233940334720009
#   (2797, 24734)	0.2888506547565673
#   (2797, 24259)	0.36748712787355753
#   (2797, 23566)	0.3877564642672896
#   (2797, 20802)	0.2583670261989798
#   (2797, 18565)	0.2817692386973227
#   (2797, 15430)	0.18224505481755687
#   (2797, 7101)	0.0956776682218143
#   (2797, 4006)	0.23559436315322568
#   (2798, 40692)	0.15568652845098263
#   (2798, 32422)	0.5175376646644959
#   (2798, 31428)	0.5175376646644959
#   (2798, 7101)	0.09885413789968994
#   (2798, 6013)	0.40305565526345083
#   (2798, 5649)	0.5175376646644959
#   (2799, 40853)	0.24502150367030695
#   (2799, 29354)	0.39503945316744965
#   (2799, 29295)	0.2093154866548374
#   (2799, 25574)	0.4591068388996091
#   (2799, 25467)	0.4339181289115427
#   (2799, 18769)	0.3576081291643306
#   (2799, 13480)	0.35656998974087206
#   (2799, 7101)	0.09804073315364431
#   (2799, 6208)	0.27639386953900485
# Test_X_Tfidf :
#    (0, 16663)	0.561419550581454
#   (0, 12164)	0.23805145594059293
#   (0, 8013)	0.2005587152148625
#   (0, 7519)	0.6562426712978519
#   (0, 2992)	0.396561912781227
#   (1, 41455)	0.4027916525226427
#   (1, 40164)	0.23300720750281068
#   (1, 32899)	0.26970431062417133
#   (1, 27520)	0.18581620535155244
#   (1, 22621)	0.3205359439762914
#   (1, 21583)	0.1870876037772382
#   (1, 19730)	0.31519375614915374
#   (1, 17600)	0.26826354021437054
#   (1, 17549)	0.141698662021964
#   (1, 8093)	0.19734335316448876
#   (1, 8013)	0.10769476058637062
#   (1, 5861)	0.24623920265677976
#   (1, 5732)	0.2799374234375938
#   (1, 1566)	0.26427623170916753
#   (1, 1166)	0.21159442454849317
#   (1, 213)	0.20714017077951108
#   (2, 42147)	0.18303271606662344
#   (2, 40509)	0.2790456678934911
#   (2, 38069)	0.30937890473777135
#   (2, 35308)	0.3219183647085779
#   :	:
#   (2797, 29295)	0.20427037866459188
#   (2797, 29289)	0.3233940334720009
#   (2797, 24734)	0.2888506547565673
#   (2797, 24259)	0.36748712787355753
#   (2797, 23566)	0.3877564642672896
#   (2797, 20802)	0.2583670261989798
#   (2797, 18565)	0.2817692386973227
#   (2797, 15430)	0.18224505481755687
#   (2797, 7101)	0.0956776682218143
#   (2797, 4006)	0.23559436315322568
#   (2798, 40692)	0.15568652845098263
#   (2798, 32422)	0.5175376646644959
#   (2798, 31428)	0.5175376646644959
#   (2798, 7101)	0.09885413789968994
#   (2798, 6013)	0.40305565526345083
#   (2798, 5649)	0.5175376646644959
#   (2799, 40853)	0.24502150367030695
#   (2799, 29354)	0.39503945316744965
#   (2799, 29295)	0.2093154866548374
#   (2799, 25574)	0.4591068388996091
#   (2799, 25467)	0.4339181289115427
#   (2799, 18769)	0.3576081291643306
#   (2799, 13480)	0.35656998974087206
#   (2799, 7101)	0.09804073315364431
#   (2799, 6208)	0.27639386953900485

# %% [markdown]
# ## Training Model Baseline

# %%
# Classifier - Algorithm - SVM
# trainig model baseline
SVM = SVC(C=3, kernel='linear')
SVM.fit(Train_X_Tfidf,Train_Y)
# Out:
# SVC(C=3, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
# predict the labels on training dataset
predictions_SVM = SVM.predict(Train_X_Tfidf)

# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score on Training Data -> ",accuracy_score(predictions_SVM, Train_Y)*100)
# Out:
# SVM Accuracy Score on Training Data ->  97.61122170269894

# %%
print(classification_report(Train_Y,predictions_SVM))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98     15512
#            1       0.95      0.97      0.96      6089
#
#     accuracy                           0.98     21601
#    macro avg       0.97      0.97      0.97     21601
# weighted avg       0.98      0.98      0.98     21601

# %%
# predict the labels on testing dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)

# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score on Testing Data -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# SVM Accuracy Score on Testing Data ->  85.07142857142857

# %%
print(classification_report(Test_Y,predictions_SVM))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      2093
#            1       0.69      0.73      0.71       707
#
#     accuracy                           0.85      2800
#    macro avg       0.80      0.81      0.81      2800
# weighted avg       0.85      0.85      0.85      2800

# %% [markdown]
# # Tuning Hyperparameter
# Proses tuning Hyperparameter sendiri terdiri dari beberapa tahapan :
#
# 1.   Untuk setiap fungsi kernel pada SVM, akan dicari parameter terbaiknya. Pencarian parameter terbaik untuk setiap fungsi kernel menggunakan GridSearch, dimana dataset yang digunakan untuk mencari hyperparameter untuk setiap fungsi kernel adalah training data. Digunakan training data karena pada GridSearch validation data akan dibuat secara otomatis berdasarkan training data.
# Algoritma GridSearch akan membagi training set menjadi 5 fold. Dalam setiap iterasi, satu fold disisihkan sebagai validation set.
# 2.   Diambil beberapa model terbaik untuk setiap fungsi kernel, kemudian dibandingkan akurasinya ketika dilatih dengan train set dan diuji pada dev dataset

# %% [markdown]
# ### Hyperparameter for 'linear' Kernel function

# %%
# defining parameter range
param_grid_linear = {'C': [0.1, 1, 10, 100, 1000], 
                    'kernel': ['linear']} 
  
grid_linear = GridSearchCV(SVC(), param_grid_linear, refit = True, verbose = 3)
  
# fitting the model for grid search
grid_linear.fit(Train_X_Tfidf, Train_Y)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END ..............C=0.1, kernel=linear;, score=0.836 total time=  24.5s
# [CV 2/5] END ..............C=0.1, kernel=linear;, score=0.838 total time=  23.6s
# [CV 3/5] END ..............C=0.1, kernel=linear;, score=0.830 total time=  23.3s
# [CV 4/5] END ..............C=0.1, kernel=linear;, score=0.829 total time=  23.1s
# [CV 5/5] END ..............C=0.1, kernel=linear;, score=0.821 total time=  27.0s
# [CV 1/5] END ................C=1, kernel=linear;, score=0.889 total time=  35.1s
# [CV 2/5] END ................C=1, kernel=linear;, score=0.864 total time=  35.4s
# [CV 3/5] END ................C=1, kernel=linear;, score=0.901 total time=  35.1s
# [CV 4/5] END ................C=1, kernel=linear;, score=0.880 total time=  43.8s
# [CV 5/5] END ................C=1, kernel=linear;, score=0.931 total time=  37.0s
# [CV 1/5] END ...............C=10, kernel=linear;, score=0.880 total time= 1.2min
# [CV 2/5] END ...............C=10, kernel=linear;, score=0.841 total time=  58.8s
# [CV 3/5] END ...............C=10, kernel=linear;, score=0.906 total time= 1.1min
# [CV 4/5] END ...............C=10, kernel=linear;, score=0.863 total time= 1.1min
# [CV 5/5] END ...............C=10, kernel=linear;, score=0.971 total time= 1.3min
# [CV 1/5] END ..............C=100, kernel=linear;, score=0.874 total time= 1.0min
# [CV 2/5] END ..............C=100, kernel=linear;, score=0.837 total time=  51.5s
# [CV 3/5] END ..............C=100, kernel=linear;, score=0.901 total time= 1.0min
# [CV 4/5] END ..............C=100, kernel=linear;, score=0.856 total time= 1.2min
# [CV 5/5] END ..............C=100, kernel=linear;, score=0.973 total time= 1.1min
# [CV 1/5] END .............C=1000, kernel=linear;, score=0.865 total time=  47.7s
# [CV 2/5] END .............C=1000, kernel=linear;, score=0.825 total time=  41.1s
# [CV 3/5] END .............C=1000, kernel=linear;, score=0.900 total time=  46.0s
# [CV 4/5] END .............C=1000, kernel=linear;, score=0.848 total time=  53.8s
# [CV 5/5] END .............C=1000, kernel=linear;, score=0.972 total time= 1.2min
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000], 'kernel': ['linear']},
#              verbose=3)

# %%
# print best parameter after tuning
print(grid_linear.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid_linear.best_estimator_)

# print best score of our model
print("best score:", grid_linear.best_score_)
# Out:
# {'C': 1, 'kernel': 'linear'}
# SVC(C=1, kernel='linear')
# best score: 0.8928755024985643

# %%
df = pd.DataFrame(grid_linear.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0      20.316258      1.523549         3.979527        0.130459     0.1
# 1      33.824874      3.320928         3.479501        0.054218       1
# 2      63.956428      6.260242         3.370167        0.053774      10
# 3      59.426163      6.912942         3.170937        0.124234     100
# 4      48.915757      9.731854         2.679627        0.072028    1000
#
#   param_kernel                           params  split0_test_score  \
# 0       linear   {'C': 0.1, 'kernel': 'linear'}           0.836380
# 1       linear     {'C': 1, 'kernel': 'linear'}           0.889146
# 2       linear    {'C': 10, 'kernel': 'linear'}           0.880120
# 3       linear   {'C': 100, 'kernel': 'linear'}           0.874335
# 4       linear  {'C': 1000, 'kernel': 'linear'}           0.864846
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.838194           0.829861           0.829167           0.820833
# 1           0.863889           0.901157           0.879630           0.930556
# 2           0.840509           0.905556           0.862963           0.971065
# 3           0.837037           0.900694           0.855787           0.972917
# 4           0.824769           0.899769           0.848148           0.972454
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.830887        0.006143                5
# 1         0.892876        0.022441                1
# 2         0.892043        0.044879                2
# 3         0.888154        0.047315                3
# 4         0.881997        0.051407                4

# %% [markdown]
# ### Hyperparameter for 'rbf' Kernel Function

# %%
# defining parameter range
param_grid_rbf = {'C': [1, 10, 100, 1000], 
              'gamma': [10, 1, 0.1, 0.01],
              'kernel': ['rbf']} 
  
grid_rbf = GridSearchCV(SVC(), param_grid_rbf, refit = True, verbose = 3)
  
# fitting the model for grid search
grid_rbf.fit(Train_X_Tfidf, Train_Y)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END .........C=1, gamma=10, kernel=rbf;, score=0.828 total time= 2.0min
# [CV 2/5] END .........C=1, gamma=10, kernel=rbf;, score=0.747 total time= 2.0min
# [CV 3/5] END .........C=1, gamma=10, kernel=rbf;, score=0.850 total time= 2.2min
# [CV 4/5] END .........C=1, gamma=10, kernel=rbf;, score=0.807 total time= 1.8min
# [CV 5/5] END .........C=1, gamma=10, kernel=rbf;, score=0.975 total time= 2.3min
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.895 total time= 1.2min
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.858 total time= 1.2min
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.909 total time= 1.2min
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.884 total time= 1.5min
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.955 total time= 1.2min
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.851 total time=  25.4s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.845 total time=  25.6s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.850 total time=  24.8s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.845 total time=  25.8s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.847 total time=  25.6s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.729 total time=  26.9s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.729 total time=  26.4s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.724 total time=  27.6s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.731 total time=  28.1s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.725 total time=  27.4s
# [CV 1/5] END ........C=10, gamma=10, kernel=rbf;, score=0.829 total time= 2.3min
# [CV 2/5] END ........C=10, gamma=10, kernel=rbf;, score=0.749 total time= 1.7min
# [CV 3/5] END ........C=10, gamma=10, kernel=rbf;, score=0.853 total time= 2.3min
# [CV 4/5] END ........C=10, gamma=10, kernel=rbf;, score=0.807 total time= 2.3min
# [CV 5/5] END ........C=10, gamma=10, kernel=rbf;, score=0.975 total time= 2.5min
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.902 total time= 1.3min
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.858 total time= 1.3min
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.917 total time= 1.4min
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.889 total time= 1.3min
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.975 total time= 1.6min
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.886 total time=  55.4s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.856 total time=  53.8s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.908 total time=  55.2s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.876 total time= 1.1min
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.952 total time=  58.7s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.852 total time=  25.1s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.848 total time=  25.4s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.855 total time=  24.7s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.851 total time=  25.1s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.854 total time=  25.9s
# [CV 1/5] END .......C=100, gamma=10, kernel=rbf;, score=0.829 total time= 2.4min
# [CV 2/5] END .......C=100, gamma=10, kernel=rbf;, score=0.749 total time= 1.8min
# [CV 3/5] END .......C=100, gamma=10, kernel=rbf;, score=0.853 total time= 2.3min
# [CV 4/5] END .......C=100, gamma=10, kernel=rbf;, score=0.807 total time= 2.3min
# [CV 5/5] END .......C=100, gamma=10, kernel=rbf;, score=0.975 total time= 2.5min
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.901 total time= 1.4min
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.859 total time= 1.3min
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.917 total time= 1.4min
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.887 total time= 1.4min
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.975 total time= 1.6min
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.886 total time= 1.3min
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.842 total time= 1.2min
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.907 total time= 1.3min
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.867 total time= 1.2min
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.975 total time= 1.5min
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.882 total time=  51.6s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.854 total time=  49.4s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.905 total time=  50.4s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.872 total time= 1.0min
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.946 total time=  53.1s
# [CV 1/5] END ......C=1000, gamma=10, kernel=rbf;, score=0.829 total time= 2.3min
# [CV 2/5] END ......C=1000, gamma=10, kernel=rbf;, score=0.749 total time= 1.8min
# [CV 3/5] END ......C=1000, gamma=10, kernel=rbf;, score=0.853 total time= 2.3min
# [CV 4/5] END ......C=1000, gamma=10, kernel=rbf;, score=0.807 total time= 2.4min
# [CV 5/5] END ......C=1000, gamma=10, kernel=rbf;, score=0.975 total time= 2.6min
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.901 total time= 1.3min
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.859 total time= 1.3min
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.917 total time= 1.4min
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.887 total time= 1.3min
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.975 total time= 1.5min
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.883 total time= 1.3min
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.844 total time= 1.1min
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.906 total time= 1.3min
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.865 total time= 1.2min
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.974 total time= 1.4min
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.875 total time= 1.1min
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.831 total time=  59.6s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.899 total time= 1.1min
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.856 total time= 1.0min
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.973 total time= 1.2min
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1, 10, 100, 1000], 'gamma': [10, 1, 0.1, 0.01],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
# print best parameter after tuning
print(grid_rbf.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid_rbf.best_estimator_)

# print best score of our model
print("best score:", grid_rbf.best_score_)
# Out:
# {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# SVC(C=10, gamma=1)
# best score: 0.9081526909923114

# %%
df = pd.DataFrame(grid_rbf.cv_results_)
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0      115.684717     11.579358         7.236692        0.436463       1
# 1       69.173716      6.842376         5.226292        0.105994       1
# 2       21.097445      0.296994         4.355670        0.146861       1
# 3       22.443417      0.515914         4.843061        0.181694       1
# 4      126.906128     15.403525         7.121416        0.474426      10
# 5       77.125201      5.785777         5.439274        0.195763      10
# 6       54.016492      5.056683         4.101626        0.128808      10
# 7       20.936452      0.411477         4.321905        0.115939      10
# 8      127.544605     14.577525         7.107888        0.556334     100
# 9       78.063438      5.745704         5.605049        0.311911     100
# 10      74.673413      5.928660         4.056555        0.150860     100
# 11      49.570579      4.696554         3.848609        0.057835     100
# 12     128.388504     15.841651         7.463911        0.582048    1000
# 13      76.790863      5.691166         5.504948        0.185837    1000
# 14      71.785972      5.785115         3.952209        0.065486    1000
# 15      61.487310      4.502709         3.574291        0.037915    1000
#
#    param_gamma param_kernel                                       params  \
# 0           10          rbf       {'C': 1, 'gamma': 10, 'kernel': 'rbf'}
# 1            1          rbf        {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
# 2          0.1          rbf      {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 3         0.01          rbf     {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 4           10          rbf      {'C': 10, 'gamma': 10, 'kernel': 'rbf'}
# 5            1          rbf       {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 6          0.1          rbf     {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 7         0.01          rbf    {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 8           10          rbf     {'C': 100, 'gamma': 10, 'kernel': 'rbf'}
# 9            1          rbf      {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 10         0.1          rbf    {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# 11        0.01          rbf   {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# 12          10          rbf    {'C': 1000, 'gamma': 10, 'kernel': 'rbf'}
# 13           1          rbf     {'C': 1000, 'gamma': 1, 'kernel': 'rbf'}
# 14         0.1          rbf   {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
# 15        0.01          rbf  {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.827818           0.747222           0.850000
# 1            0.895163           0.857639           0.908796
# 2            0.851423           0.845370           0.850231
# 3            0.729461           0.728704           0.724074
# 4            0.828975           0.748843           0.852546
# 5            0.901875           0.857870           0.916898
# 6            0.886137           0.856250           0.908333
# 7            0.851655           0.847917           0.854630
# 8            0.828975           0.748843           0.852546
# 9            0.901412           0.858796           0.916898
# 10           0.886137           0.842130           0.906713
# 11           0.882435           0.854398           0.904861
# 12           0.828975           0.748843           0.852546
# 13           0.901180           0.858565           0.916898
# 14           0.882897           0.843519           0.905787
# 15           0.874798           0.831250           0.898843
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.807176           0.975463         0.841536        0.075196
# 1            0.884259           0.955093         0.900190        0.032181
# 2            0.845370           0.847454         0.847970        0.002483
# 3            0.731481           0.724769         0.727698        0.002834
# 4            0.807176           0.975463         0.842601        0.074810
# 5            0.888889           0.975231         0.908153        0.038768
# 6            0.876389           0.951620         0.895746        0.032580
# 7            0.850926           0.854167         0.851859        0.002427
# 8            0.807176           0.975463         0.842601        0.074810
# 9            0.887037           0.975463         0.907921        0.038818
# 10           0.867361           0.974537         0.895376        0.044945
# 11           0.871991           0.946296         0.891996        0.031684
# 12           0.807176           0.975463         0.842601        0.074810
# 13           0.887037           0.975463         0.907829        0.038885
# 14           0.865278           0.973843         0.894265        0.044744
# 15           0.855556           0.973148         0.886719        0.048594
#
#     rank_test_score
# 0                15
# 1                 4
# 2                11
# 3                16
# 4                12
# 5                 1
# 6                 5
# 7                10
# 8                12
# 9                 2
# 10                6
# 11                8
# 12               12
# 13                3
# 14                7
# 15                9

# %% [markdown]
# ### Hyperparameter for 'poly' Kernel Function

# %%
# defining parameter range
param_grid_poly = {'C': [0.8],
              'degree': [1, 2, 3, 4],
              'gamma': ['scale', 10, 1],
              'kernel': ['poly']} 
  
grid_poly = GridSearchCV(SVC(), param_grid_poly, refit = True, verbose = 3)
  
# fitting the model for grid search
grid_poly.fit(Train_X_Tfidf, Train_Y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END C=0.8, degree=1, gamma=scale, kernel=poly;, score=0.884 total time=  30.7s
# [CV 2/5] END C=0.8, degree=1, gamma=scale, kernel=poly;, score=0.867 total time=  38.1s
# [CV 3/5] END C=0.8, degree=1, gamma=scale, kernel=poly;, score=0.892 total time=  29.3s
# [CV 4/5] END C=0.8, degree=1, gamma=scale, kernel=poly;, score=0.878 total time=  37.1s
# [CV 5/5] END C=0.8, degree=1, gamma=scale, kernel=poly;, score=0.919 total time=  30.9s
# [CV 1/5] END C=0.8, degree=1, gamma=10, kernel=poly;, score=0.876 total time=  59.0s
# [CV 2/5] END C=0.8, degree=1, gamma=10, kernel=poly;, score=0.837 total time=  54.4s
# [CV 3/5] END C=0.8, degree=1, gamma=10, kernel=poly;, score=0.905 total time=  58.2s
# [CV 4/5] END C=0.8, degree=1, gamma=10, kernel=poly;, score=0.859 total time=  56.7s
# [CV 5/5] END C=0.8, degree=1, gamma=10, kernel=poly;, score=0.971 total time= 1.1min
# [CV 1/5] END C=0.8, degree=1, gamma=1, kernel=poly;, score=0.884 total time=  30.7s
# [CV 2/5] END C=0.8, degree=1, gamma=1, kernel=poly;, score=0.867 total time=  30.4s
# [CV 3/5] END C=0.8, degree=1, gamma=1, kernel=poly;, score=0.892 total time=  30.5s
# [CV 4/5] END C=0.8, degree=1, gamma=1, kernel=poly;, score=0.878 total time=  38.1s
# [CV 5/5] END C=0.8, degree=1, gamma=1, kernel=poly;, score=0.919 total time=  30.7s
# [CV 1/5] END C=0.8, degree=2, gamma=scale, kernel=poly;, score=0.879 total time= 1.3min
# [CV 2/5] END C=0.8, degree=2, gamma=scale, kernel=poly;, score=0.827 total time= 1.2min
# [CV 3/5] END C=0.8, degree=2, gamma=scale, kernel=poly;, score=0.889 total time= 1.3min
# [CV 4/5] END C=0.8, degree=2, gamma=scale, kernel=poly;, score=0.859 total time= 1.3min
# [CV 5/5] END C=0.8, degree=2, gamma=scale, kernel=poly;, score=0.957 total time= 1.4min
# [CV 1/5] END C=0.8, degree=2, gamma=10, kernel=poly;, score=0.885 total time= 1.5min
# [CV 2/5] END C=0.8, degree=2, gamma=10, kernel=poly;, score=0.834 total time= 1.4min
# [CV 3/5] END C=0.8, degree=2, gamma=10, kernel=poly;, score=0.900 total time= 1.6min
# [CV 4/5] END C=0.8, degree=2, gamma=10, kernel=poly;, score=0.868 total time= 1.5min
# [CV 5/5] END C=0.8, degree=2, gamma=10, kernel=poly;, score=0.973 total time= 1.8min
# [CV 1/5] END C=0.8, degree=2, gamma=1, kernel=poly;, score=0.878 total time= 1.3min
# [CV 2/5] END C=0.8, degree=2, gamma=1, kernel=poly;, score=0.827 total time= 1.2min
# [CV 3/5] END C=0.8, degree=2, gamma=1, kernel=poly;, score=0.889 total time= 1.3min
# [CV 4/5] END C=0.8, degree=2, gamma=1, kernel=poly;, score=0.859 total time= 1.3min
# [CV 5/5] END C=0.8, degree=2, gamma=1, kernel=poly;, score=0.957 total time= 1.4min
# [CV 1/5] END C=0.8, degree=3, gamma=scale, kernel=poly;, score=0.847 total time= 1.3min
# [CV 2/5] END C=0.8, degree=3, gamma=scale, kernel=poly;, score=0.773 total time= 1.3min
# [CV 3/5] END C=0.8, degree=3, gamma=scale, kernel=poly;, score=0.867 total time= 1.4min
# [CV 4/5] END C=0.8, degree=3, gamma=scale, kernel=poly;, score=0.823 total time= 1.4min
# [CV 5/5] END C=0.8, degree=3, gamma=scale, kernel=poly;, score=0.970 total time= 1.7min
# [CV 1/5] END C=0.8, degree=3, gamma=10, kernel=poly;, score=0.849 total time= 2.2min
# [CV 2/5] END C=0.8, degree=3, gamma=10, kernel=poly;, score=0.777 total time= 1.8min
# [CV 3/5] END C=0.8, degree=3, gamma=10, kernel=poly;, score=0.866 total time= 2.3min
# [CV 4/5] END C=0.8, degree=3, gamma=10, kernel=poly;, score=0.825 total time= 2.1min
# [CV 5/5] END C=0.8, degree=3, gamma=10, kernel=poly;, score=0.973 total time= 2.4min
# [CV 1/5] END C=0.8, degree=3, gamma=1, kernel=poly;, score=0.846 total time= 1.3min
# [CV 2/5] END C=0.8, degree=3, gamma=1, kernel=poly;, score=0.773 total time= 1.3min
# [CV 3/5] END C=0.8, degree=3, gamma=1, kernel=poly;, score=0.867 total time= 1.4min
# [CV 4/5] END C=0.8, degree=3, gamma=1, kernel=poly;, score=0.824 total time= 1.3min
# [CV 5/5] END C=0.8, degree=3, gamma=1, kernel=poly;, score=0.970 total time= 1.6min
# [CV 1/5] END C=0.8, degree=4, gamma=scale, kernel=poly;, score=0.837 total time= 1.4min
# [CV 2/5] END C=0.8, degree=4, gamma=scale, kernel=poly;, score=0.760 total time= 1.4min
# [CV 3/5] END C=0.8, degree=4, gamma=scale, kernel=poly;, score=0.858 total time= 1.7min
# [CV 4/5] END C=0.8, degree=4, gamma=scale, kernel=poly;, score=0.813 total time= 1.4min
# [CV 5/5] END C=0.8, degree=4, gamma=scale, kernel=poly;, score=0.974 total time= 1.7min
# [CV 1/5] END C=0.8, degree=4, gamma=10, kernel=poly;, score=0.839 total time= 3.8min
# [CV 2/5] END C=0.8, degree=4, gamma=10, kernel=poly;, score=0.763 total time= 3.5min
# [CV 3/5] END C=0.8, degree=4, gamma=10, kernel=poly;, score=0.861 total time= 4.0min
# [CV 4/5] END C=0.8, degree=4, gamma=10, kernel=poly;, score=0.815 total time= 3.7min
# [CV 5/5] END C=0.8, degree=4, gamma=10, kernel=poly;, score=0.975 total time= 4.5min
# [CV 1/5] END C=0.8, degree=4, gamma=1, kernel=poly;, score=0.837 total time= 1.4min
# [CV 2/5] END C=0.8, degree=4, gamma=1, kernel=poly;, score=0.760 total time= 1.4min
# [CV 3/5] END C=0.8, degree=4, gamma=1, kernel=poly;, score=0.858 total time= 1.6min
# [CV 4/5] END C=0.8, degree=4, gamma=1, kernel=poly;, score=0.813 total time= 1.4min
# [CV 5/5] END C=0.8, degree=4, gamma=1, kernel=poly;, score=0.974 total time= 1.7min
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.8], 'degree': [1, 2, 3, 4],
#                          'gamma': ['scale', 10, 1], 'kernel': ['poly']},
#              verbose=3)

# %%
# print best parameter after tuning
print(grid_poly.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid_poly.best_estimator_)

# print best score of our model
print("best score:", grid_poly.best_score_)
# Out:
# {'C': 0.8, 'degree': 2, 'gamma': 10, 'kernel': 'poly'}
# SVC(C=0.8, degree=2, gamma=10, kernel='poly')
# best score: 0.8920423513075677

# %%
df = pd.DataFrame(grid_poly.cv_results_)
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       29.831154      3.579260         3.401851        0.058337     0.8
# 1       55.764358      3.990845         3.147194        0.039646     0.8
# 2       28.543812      2.758454         3.537546        0.229150     0.8
# 3       72.259203      3.355577         5.955672        0.214520     0.8
# 4       89.109700      7.688519         5.766266        0.289795     0.8
# 5       71.740839      2.790335         5.944163        0.192752     0.8
# 6       78.515976      8.064723         6.439794        0.364684     0.8
# 7      122.664263     12.443790         6.289253        0.243724     0.8
# 8       77.912126      7.341287         6.271462        0.295633     0.8
# 9       85.151635      8.542412         6.475238        0.329882     0.8
# 10     227.372341     19.588458         5.919795        0.264991     0.8
# 11      83.821270      8.138597         6.226716        0.228854     0.8
#
#    param_degree param_gamma param_kernel  \
# 0             1       scale         poly
# 1             1          10         poly
# 2             1           1         poly
# 3             2       scale         poly
# 4             2          10         poly
# 5             2           1         poly
# 6             3       scale         poly
# 7             3          10         poly
# 8             3           1         poly
# 9             4       scale         poly
# 10            4          10         poly
# 11            4           1         poly
#
#                                                params  split0_test_score  \
# 0   {'C': 0.8, 'degree': 1, 'gamma': 'scale', 'ker...           0.883823
# 1   {'C': 0.8, 'degree': 1, 'gamma': 10, 'kernel':...           0.876186
# 2   {'C': 0.8, 'degree': 1, 'gamma': 1, 'kernel': ...           0.883823
# 3   {'C': 0.8, 'degree': 2, 'gamma': 'scale', 'ker...           0.878500
# 4   {'C': 0.8, 'degree': 2, 'gamma': 10, 'kernel':...           0.885212
# 5   {'C': 0.8, 'degree': 2, 'gamma': 1, 'kernel': ...           0.878269
# 6   {'C': 0.8, 'degree': 3, 'gamma': 'scale', 'ker...           0.846795
# 7   {'C': 0.8, 'degree': 3, 'gamma': 10, 'kernel':...           0.848878
# 8   {'C': 0.8, 'degree': 3, 'gamma': 1, 'kernel': ...           0.846332
# 9   {'C': 0.8, 'degree': 4, 'gamma': 'scale', 'ker...           0.837306
# 10  {'C': 0.8, 'degree': 4, 'gamma': 10, 'kernel':...           0.838926
# 11  {'C': 0.8, 'degree': 4, 'gamma': 1, 'kernel': ...           0.837306
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.867130           0.892361           0.878009
# 1            0.837037           0.904630           0.859028
# 2            0.866898           0.892361           0.878009
# 3            0.827315           0.889352           0.859259
# 4            0.833565           0.899769           0.868287
# 5            0.827315           0.889352           0.859259
# 6            0.773380           0.866898           0.823380
# 7            0.776852           0.866204           0.825000
# 8            0.773380           0.866898           0.823611
# 9            0.760417           0.858333           0.813426
# 10           0.763426           0.860648           0.815278
# 11           0.760185           0.858333           0.813426
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.918981         0.888061        0.017502                3
# 1            0.971296         0.889635        0.046428                2
# 2            0.919213         0.888061        0.017640                3
# 3            0.956713         0.882228        0.042792                6
# 4            0.973380         0.892042        0.046273                1
# 5            0.956944         0.882228        0.042877                5
# 6            0.970139         0.856118        0.064994                8
# 7            0.972685         0.857924        0.064772                7
# 8            0.970139         0.856072        0.064985                9
# 9            0.974306         0.848758        0.070764               11
# 10           0.974769         0.850609        0.070003               10
# 11           0.974306         0.848711        0.070822               12

# %% [markdown]
# ### Hyperparameter for 'sigmoid' Kernel Function

# %%
# defining parameter range
param_grid_sig = {'C': [0.5, 0.6, 0.8, 1],
              'degree': [3],
              'gamma': ['scale', 10, 1, 0.1],
              'kernel': ['sigmoid']} 
  
grid_sig = GridSearchCV(SVC(), param_grid_sig, refit = True, verbose = 3)
  
# fitting the model for grid search
grid_sig.fit(Train_X_Tfidf, Train_Y)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END C=0.5, degree=3, gamma=scale, kernel=sigmoid;, score=0.870 total time=  21.8s
# [CV 2/5] END C=0.5, degree=3, gamma=scale, kernel=sigmoid;, score=0.866 total time=  21.7s
# [CV 3/5] END C=0.5, degree=3, gamma=scale, kernel=sigmoid;, score=0.873 total time=  22.0s
# [CV 4/5] END C=0.5, degree=3, gamma=scale, kernel=sigmoid;, score=0.867 total time=  21.4s
# [CV 5/5] END C=0.5, degree=3, gamma=scale, kernel=sigmoid;, score=0.882 total time=  21.7s
# [CV 1/5] END C=0.5, degree=3, gamma=10, kernel=sigmoid;, score=0.782 total time=  15.2s
# [CV 2/5] END C=0.5, degree=3, gamma=10, kernel=sigmoid;, score=0.797 total time=  14.6s
# [CV 3/5] END C=0.5, degree=3, gamma=10, kernel=sigmoid;, score=0.772 total time=  15.1s
# [CV 4/5] END C=0.5, degree=3, gamma=10, kernel=sigmoid;, score=0.766 total time=  14.9s
# [CV 5/5] END C=0.5, degree=3, gamma=10, kernel=sigmoid;, score=0.779 total time=  15.5s
# [CV 1/5] END C=0.5, degree=3, gamma=1, kernel=sigmoid;, score=0.870 total time=  21.7s
# [CV 2/5] END C=0.5, degree=3, gamma=1, kernel=sigmoid;, score=0.866 total time=  21.9s
# [CV 3/5] END C=0.5, degree=3, gamma=1, kernel=sigmoid;, score=0.873 total time=  21.6s
# [CV 4/5] END C=0.5, degree=3, gamma=1, kernel=sigmoid;, score=0.867 total time=  21.8s
# [CV 5/5] END C=0.5, degree=3, gamma=1, kernel=sigmoid;, score=0.883 total time=  22.5s
# [CV 1/5] END C=0.5, degree=3, gamma=0.1, kernel=sigmoid;, score=0.796 total time=  25.8s
# [CV 2/5] END C=0.5, degree=3, gamma=0.1, kernel=sigmoid;, score=0.797 total time=  25.7s
# [CV 3/5] END C=0.5, degree=3, gamma=0.1, kernel=sigmoid;, score=0.784 total time=  25.2s
# [CV 4/5] END C=0.5, degree=3, gamma=0.1, kernel=sigmoid;, score=0.791 total time=  25.7s
# [CV 5/5] END C=0.5, degree=3, gamma=0.1, kernel=sigmoid;, score=0.777 total time=  25.5s
# [CV 1/5] END C=0.6, degree=3, gamma=scale, kernel=sigmoid;, score=0.873 total time=  21.7s
# [CV 2/5] END C=0.6, degree=3, gamma=scale, kernel=sigmoid;, score=0.867 total time=  21.8s
# [CV 3/5] END C=0.6, degree=3, gamma=scale, kernel=sigmoid;, score=0.875 total time=  21.9s
# [CV 4/5] END C=0.6, degree=3, gamma=scale, kernel=sigmoid;, score=0.871 total time=  22.1s
# [CV 5/5] END C=0.6, degree=3, gamma=scale, kernel=sigmoid;, score=0.891 total time=  22.0s
# [CV 1/5] END C=0.6, degree=3, gamma=10, kernel=sigmoid;, score=0.784 total time=  15.4s
# [CV 2/5] END C=0.6, degree=3, gamma=10, kernel=sigmoid;, score=0.795 total time=  15.0s
# [CV 3/5] END C=0.6, degree=3, gamma=10, kernel=sigmoid;, score=0.769 total time=  14.5s
# [CV 4/5] END C=0.6, degree=3, gamma=10, kernel=sigmoid;, score=0.765 total time=  14.2s
# [CV 5/5] END C=0.6, degree=3, gamma=10, kernel=sigmoid;, score=0.773 total time=  14.6s
# [CV 1/5] END C=0.6, degree=3, gamma=1, kernel=sigmoid;, score=0.873 total time=  22.3s
# [CV 2/5] END C=0.6, degree=3, gamma=1, kernel=sigmoid;, score=0.867 total time=  21.9s
# [CV 3/5] END C=0.6, degree=3, gamma=1, kernel=sigmoid;, score=0.875 total time=  22.0s
# [CV 4/5] END C=0.6, degree=3, gamma=1, kernel=sigmoid;, score=0.871 total time=  21.4s
# [CV 5/5] END C=0.6, degree=3, gamma=1, kernel=sigmoid;, score=0.891 total time=  21.9s
# [CV 1/5] END C=0.6, degree=3, gamma=0.1, kernel=sigmoid;, score=0.807 total time=  26.2s
# [CV 2/5] END C=0.6, degree=3, gamma=0.1, kernel=sigmoid;, score=0.808 total time=  25.3s
# [CV 3/5] END C=0.6, degree=3, gamma=0.1, kernel=sigmoid;, score=0.797 total time=  25.1s
# [CV 4/5] END C=0.6, degree=3, gamma=0.1, kernel=sigmoid;, score=0.801 total time=  25.5s
# [CV 5/5] END C=0.6, degree=3, gamma=0.1, kernel=sigmoid;, score=0.786 total time=  25.6s
# [CV 1/5] END C=0.8, degree=3, gamma=scale, kernel=sigmoid;, score=0.873 total time=  22.0s
# [CV 2/5] END C=0.8, degree=3, gamma=scale, kernel=sigmoid;, score=0.866 total time=  21.4s
# [CV 3/5] END C=0.8, degree=3, gamma=scale, kernel=sigmoid;, score=0.877 total time=  21.2s
# [CV 4/5] END C=0.8, degree=3, gamma=scale, kernel=sigmoid;, score=0.871 total time=  21.3s
# [CV 5/5] END C=0.8, degree=3, gamma=scale, kernel=sigmoid;, score=0.897 total time=  21.9s
# [CV 1/5] END C=0.8, degree=3, gamma=10, kernel=sigmoid;, score=0.766 total time=  15.5s
# [CV 2/5] END C=0.8, degree=3, gamma=10, kernel=sigmoid;, score=0.779 total time=  15.7s
# [CV 3/5] END C=0.8, degree=3, gamma=10, kernel=sigmoid;, score=0.768 total time=  15.6s
# [CV 4/5] END C=0.8, degree=3, gamma=10, kernel=sigmoid;, score=0.762 total time=  14.0s
# [CV 5/5] END C=0.8, degree=3, gamma=10, kernel=sigmoid;, score=0.775 total time=  14.4s
# [CV 1/5] END C=0.8, degree=3, gamma=1, kernel=sigmoid;, score=0.873 total time=  21.7s
# [CV 2/5] END C=0.8, degree=3, gamma=1, kernel=sigmoid;, score=0.867 total time=  22.0s
# [CV 3/5] END C=0.8, degree=3, gamma=1, kernel=sigmoid;, score=0.876 total time=  22.1s
# [CV 4/5] END C=0.8, degree=3, gamma=1, kernel=sigmoid;, score=0.871 total time=  21.4s
# [CV 5/5] END C=0.8, degree=3, gamma=1, kernel=sigmoid;, score=0.897 total time=  22.1s
# [CV 1/5] END C=0.8, degree=3, gamma=0.1, kernel=sigmoid;, score=0.822 total time=  25.1s
# [CV 2/5] END C=0.8, degree=3, gamma=0.1, kernel=sigmoid;, score=0.825 total time=  25.0s
# [CV 3/5] END C=0.8, degree=3, gamma=0.1, kernel=sigmoid;, score=0.816 total time=  25.6s
# [CV 4/5] END C=0.8, degree=3, gamma=0.1, kernel=sigmoid;, score=0.813 total time=  24.9s
# [CV 5/5] END C=0.8, degree=3, gamma=0.1, kernel=sigmoid;, score=0.806 total time=  25.5s
# [CV 1/5] END C=1, degree=3, gamma=scale, kernel=sigmoid;, score=0.873 total time=  22.0s
# [CV 2/5] END C=1, degree=3, gamma=scale, kernel=sigmoid;, score=0.864 total time=  27.6s
# [CV 3/5] END C=1, degree=3, gamma=scale, kernel=sigmoid;, score=0.879 total time=  22.2s
# [CV 4/5] END C=1, degree=3, gamma=scale, kernel=sigmoid;, score=0.870 total time=  28.5s
# [CV 5/5] END C=1, degree=3, gamma=scale, kernel=sigmoid;, score=0.903 total time=  22.0s
# [CV 1/5] END C=1, degree=3, gamma=10, kernel=sigmoid;, score=0.764 total time=  14.6s
# [CV 2/5] END C=1, degree=3, gamma=10, kernel=sigmoid;, score=0.780 total time=  14.2s
# [CV 3/5] END C=1, degree=3, gamma=10, kernel=sigmoid;, score=0.766 total time=  17.6s
# [CV 4/5] END C=1, degree=3, gamma=10, kernel=sigmoid;, score=0.760 total time=  14.6s
# [CV 5/5] END C=1, degree=3, gamma=10, kernel=sigmoid;, score=0.770 total time=  14.2s
# [CV 1/5] END C=1, degree=3, gamma=1, kernel=sigmoid;, score=0.873 total time=  23.1s
# [CV 2/5] END C=1, degree=3, gamma=1, kernel=sigmoid;, score=0.864 total time=  23.2s
# [CV 3/5] END C=1, degree=3, gamma=1, kernel=sigmoid;, score=0.879 total time=  21.2s
# [CV 4/5] END C=1, degree=3, gamma=1, kernel=sigmoid;, score=0.870 total time=  26.7s
# [CV 5/5] END C=1, degree=3, gamma=1, kernel=sigmoid;, score=0.904 total time=  22.3s
# [CV 1/5] END C=1, degree=3, gamma=0.1, kernel=sigmoid;, score=0.836 total time=  25.0s
# [CV 2/5] END C=1, degree=3, gamma=0.1, kernel=sigmoid;, score=0.832 total time=  25.1s
# [CV 3/5] END C=1, degree=3, gamma=0.1, kernel=sigmoid;, score=0.826 total time=  24.7s
# [CV 4/5] END C=1, degree=3, gamma=0.1, kernel=sigmoid;, score=0.824 total time=  25.3s
# [CV 5/5] END C=1, degree=3, gamma=0.1, kernel=sigmoid;, score=0.818 total time=  25.1s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.5, 0.6, 0.8, 1], 'degree': [3],
#                          'gamma': ['scale', 10, 1, 0.1],
#                          'kernel': ['sigmoid']},
#              verbose=3)

# %%
# print best parameter after tuning
print(grid_sig.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid_sig.best_estimator_)

# print best score of our model
print("best score:", grid_sig.best_score_)
# Out:
# {'C': 1, 'degree': 3, 'gamma': 1, 'kernel': 'sigmoid'}
# SVC(C=1, gamma=1, kernel='sigmoid')
# best score: 0.8778762524964214

# %%
df = pd.DataFrame(grid_sig.cv_results_)
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       18.261599      0.243683         3.439074        0.100563     0.5
# 1       12.929625      0.343190         2.142879        0.065090     0.5
# 2       18.445197      0.380835         3.459070        0.089973     0.5
# 3       21.269064      0.175990         4.318898        0.085481     0.5
# 4       18.476256      0.169109         3.448660        0.091623     0.6
# 5       12.617117      0.398438         2.119847        0.062952     0.6
# 6       18.470560      0.324417         3.446907        0.098428     0.6
# 7       21.212342      0.407210         4.307342        0.113961     0.6
# 8       18.198399      0.402310         3.343030        0.067598     0.8
# 9       12.894421      0.658138         2.148131        0.128169     0.8
# 10      18.458147      0.308054         3.368135        0.084719     0.8
# 11      20.959909      0.360059         4.261154        0.110067     0.8
# 12      21.121740      2.868975         3.326012        0.072809       1
# 13      12.978441      1.319176         2.058469        0.062190       1
# 14      19.988080      1.786115         3.318187        0.076801       1
# 15      20.834512      0.188916         4.207115        0.135898       1
#
#    param_degree param_gamma param_kernel  \
# 0             3       scale      sigmoid
# 1             3          10      sigmoid
# 2             3           1      sigmoid
# 3             3         0.1      sigmoid
# 4             3       scale      sigmoid
# 5             3          10      sigmoid
# 6             3           1      sigmoid
# 7             3         0.1      sigmoid
# 8             3       scale      sigmoid
# 9             3          10      sigmoid
# 10            3           1      sigmoid
# 11            3         0.1      sigmoid
# 12            3       scale      sigmoid
# 13            3          10      sigmoid
# 14            3           1      sigmoid
# 15            3         0.1      sigmoid
#
#                                                params  split0_test_score  \
# 0   {'C': 0.5, 'degree': 3, 'gamma': 'scale', 'ker...           0.869706
# 1   {'C': 0.5, 'degree': 3, 'gamma': 10, 'kernel':...           0.781995
# 2   {'C': 0.5, 'degree': 3, 'gamma': 1, 'kernel': ...           0.869706
# 3   {'C': 0.5, 'degree': 3, 'gamma': 0.1, 'kernel'...           0.795881
# 4   {'C': 0.6, 'degree': 3, 'gamma': 'scale', 'ker...           0.872715
# 5   {'C': 0.6, 'degree': 3, 'gamma': 10, 'kernel':...           0.784078
# 6   {'C': 0.6, 'degree': 3, 'gamma': 1, 'kernel': ...           0.872715
# 7   {'C': 0.6, 'degree': 3, 'gamma': 0.1, 'kernel'...           0.807221
# 8   {'C': 0.8, 'degree': 3, 'gamma': 'scale', 'ker...           0.873178
# 9   {'C': 0.8, 'degree': 3, 'gamma': 10, 'kernel':...           0.765795
# 10  {'C': 0.8, 'degree': 3, 'gamma': 1, 'kernel': ...           0.873178
# 11  {'C': 0.8, 'degree': 3, 'gamma': 0.1, 'kernel'...           0.821569
# 12  {'C': 1, 'degree': 3, 'gamma': 'scale', 'kerne...           0.872715
# 13  {'C': 1, 'degree': 3, 'gamma': 10, 'kernel': '...           0.764175
# 14  {'C': 1, 'degree': 3, 'gamma': 1, 'kernel': 's...           0.872946
# 15  {'C': 1, 'degree': 3, 'gamma': 0.1, 'kernel': ...           0.835686
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.865972           0.872685           0.867130
# 1            0.796991           0.771528           0.766204
# 2            0.865972           0.872685           0.867130
# 3            0.797222           0.784028           0.791435
# 4            0.867130           0.875231           0.871296
# 5            0.795139           0.768750           0.764815
# 6            0.867130           0.875463           0.871296
# 7            0.808333           0.796759           0.801389
# 8            0.865741           0.876620           0.870833
# 9            0.779167           0.768287           0.761806
# 10           0.866667           0.876389           0.870833
# 11           0.824537           0.816435           0.813194
# 12           0.863889           0.878935           0.869676
# 13           0.780093           0.766204           0.759954
# 14           0.864120           0.878704           0.869676
# 15           0.831944           0.826389           0.824074
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.882407         0.871580        0.005886                8
# 1            0.779398         0.779223        0.010508               13
# 2            0.882639         0.871626        0.005971                7
# 3            0.776620         0.789037        0.007731               12
# 4            0.890741         0.875423        0.008097                6
# 5            0.773148         0.777186        0.011048               14
# 6            0.890741         0.875469        0.008097                5
# 7            0.786343         0.800009        0.008007               11
# 8            0.896991         0.876673        0.010758                4
# 9            0.774537         0.769918        0.006202               15
# 10           0.896991         0.876811        0.010576                3
# 11           0.806019         0.816351        0.006496               10
# 12           0.903241         0.877691        0.013666                2
# 13           0.769676         0.768020        0.006806               16
# 14           0.903935         0.877876        0.013860                1
# 15           0.817593         0.827137        0.006281                9

# %% [markdown]
# ## Train some best model for each kernel function and test it to validation (dev) dataset to get hyperparameter for final SVM model

# %% [markdown]
# ### Best model of 'linear' kernel function

# %%
# best model 1
SVM_Hyper_linear = SVC(C=1, kernel='linear')
SVM_Hyper_linear.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_Linear = SVM_Hyper_linear.predict(Dev_X_Tfidf)
print("SVM Hyper Linear 1 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_Linear, Dev_Y)*100)
# Out:
# SVM Hyper Linear 1 Accuracy Score ->  86.64285714285714

# %%
# best model 2
SVM_Hyper_linear = SVC(C=10, kernel='linear')
SVM_Hyper_linear.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_Linear = SVM_Hyper_linear.predict(Dev_X_Tfidf)
print("SVM Hyper Linear 2 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_Linear, Dev_Y)*100)
# Out:
# SVM Hyper Linear 2 Accuracy Score ->  83.78571428571429

# %% [markdown]
# ### Best model of 'rbf' kernel function

# %%
# best model 1
SVM_Hyper_rbf = SVC(C=10, gamma=1)
SVM_Hyper_rbf.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_rbf = SVM_Hyper_rbf.predict(Dev_X_Tfidf)
print("SVM Hyper rbf 1 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_rbf, Dev_Y)*100)
# Out:
# SVM Hyper rbf 1 Accuracy Score ->  86.96428571428572

# %%
# best model 2
SVM_Hyper_rbf = SVC(C=100, gamma=1)
SVM_Hyper_rbf.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_rbf = SVM_Hyper_rbf.predict(Dev_X_Tfidf)
print("SVM Hyper rbf 3 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_rbf, Dev_Y)*100)
# Out:
# SVM Hyper rbf 3 Accuracy Score ->  86.92857142857143

# %%
# best model 3
SVM_Hyper_rbf = SVC(C=1000, gamma=1)
SVM_Hyper_rbf.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_rbf = SVM_Hyper_rbf.predict(Dev_X_Tfidf)
print("SVM Hyper rbf 2 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_rbf, Dev_Y)*100)
# Out:
# SVM Hyper rbf 2 Accuracy Score ->  86.92857142857143

# %%
# best model 4
SVM_Hyper_rbf = SVC(C=1, gamma=1)
SVM_Hyper_rbf.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_rbf = SVM_Hyper_rbf.predict(Dev_X_Tfidf)
print("SVM Hyper rbf 4 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_rbf, Dev_Y)*100)
# Out:
# SVM Hyper rbf 4 Accuracy Score ->  87.07142857142857

# %%
# best model 5
SVM_Hyper_rbf = SVC(C=10, gamma=0.1)
SVM_Hyper_rbf.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_rbf = SVM_Hyper_rbf.predict(Dev_X_Tfidf)
print("SVM Hyper rbf 5 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_rbf, Dev_Y)*100)
# Out:
# SVM Hyper rbf 5 Accuracy Score ->  85.57142857142857

# %% [markdown]
# ### Best model of 'poly' kernel function

# %%
# best model 1
SVM_Hyper_poly = SVC(C=0.8, degree=2, gamma=10, kernel='poly')
SVM_Hyper_poly.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_poly = SVM_Hyper_poly.predict(Dev_X_Tfidf)
print("SVM Hyper poly 1 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_poly, Dev_Y)*100)
# Out:
# SVM Hyper poly 1 Accuracy Score ->  85.03571428571428

# %%
# best model 2
SVM_Hyper_poly = SVC(C=0.8, degree=1, gamma=10, kernel='poly')
SVM_Hyper_poly.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_poly = SVM_Hyper_poly.predict(Dev_X_Tfidf)
print("SVM Hyper poly 2 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_poly, Dev_Y)*100)
# Out:
# SVM Hyper poly 2 Accuracy Score ->  84.07142857142857

# %%
# best model 3
SVM_Hyper_poly = SVC(C=0.8, degree=1, gamma=1, kernel='poly')
SVM_Hyper_poly.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_poly = SVM_Hyper_poly.predict(Dev_X_Tfidf)
print("SVM Hyper poly 3 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_poly, Dev_Y)*100)
# Out:
# SVM Hyper poly 3 Accuracy Score ->  86.60714285714286

# %%
# best model 4
SVM_Hyper_poly = SVC(C=0.8, degree=1, gamma='scale', kernel='poly')
SVM_Hyper_poly.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_poly = SVM_Hyper_poly.predict(Dev_X_Tfidf)
print("SVM Hyper poly 4 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_poly, Dev_Y)*100)
# Out:
# SVM Hyper poly 4 Accuracy Score ->  86.60714285714286

# %% [markdown]
# ### Best model of 'sigmoid' kernel function

# %%
# best model 1
SVM_Hyper_sig = SVC(C=1, gamma=1, kernel='sigmoid')
SVM_Hyper_sig.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_sig = SVM_Hyper_sig.predict(Dev_X_Tfidf)
print("SVM Hyper sigmoid 1 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_sig, Dev_Y)*100)
# Out:
# SVM Hyper sigmoid 1 Accuracy Score ->  86.35714285714286

# %%
# best model 2
SVM_Hyper_sig = SVC(C=1, gamma='scale', kernel='sigmoid')
SVM_Hyper_sig.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_sig = SVM_Hyper_sig.predict(Dev_X_Tfidf)
print("SVM Hyper sigmoid 2 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_sig, Dev_Y)*100)
# Out:
# SVM Hyper sigmoid 2 Accuracy Score ->  86.32142857142857

# %%
# best model 3
SVM_Hyper_sig = SVC(C=0.8, gamma=1, kernel='sigmoid')
SVM_Hyper_sig.fit(Train_X_Tfidf,Train_Y)

# predict the labels on dev dataset
predictions_SVM_Hyper_sig = SVM_Hyper_sig.predict(Dev_X_Tfidf)
print("SVM Hyper sigmoid 3 Accuracy Score -> ",accuracy_score(predictions_SVM_Hyper_sig, Dev_Y)*100)
# Out:
# SVM Hyper sigmoid 3 Accuracy Score ->  86.64285714285714

# %% [markdown]
# ## Hyperparamenter result

# %% [markdown]
# berdasarkan hasil tuning hyperparameter yang telah dilakukan pada kedua tahapan di atas, didapatkan bahwa paramater terbaik untuk model SVM adalah (C=1, gamma=1, kernel='rbf')

# %% [markdown]
# # Training Model with Hyperparameter

# %%
# Classifier - Algorithm - SVM
# trainig with hyper parameter
SVM_Final = SVC(C=1, gamma=1, kernel='rbf')
SVM_Final.fit(Train_X_Tfidf,Train_Y)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
# predict the labels on training dataset
predictions_SVM_Final = SVM_Final.predict(Train_X_Tfidf)

# Use accuracy_score function to get the accuracy
print("SVM Final Model (with hyperparameter) Accuracy Score on Training Data -> ",accuracy_score(predictions_SVM_Final, Train_Y)*100)
# Out:
# SVM Final Model (with hyperparameter) Accuracy Score on Training Data ->  97.81028656080737

# %%
print(classification_report(Train_Y,predictions_SVM_Final))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     15512
#            1       0.97      0.96      0.96      6089
#
#     accuracy                           0.98     21601
#    macro avg       0.97      0.97      0.97     21601
# weighted avg       0.98      0.98      0.98     21601

# %%
# predict the labels on testing dataset
predictions_SVM_Final = SVM_Final.predict(Test_X_Tfidf)

# Use accuracy_score function to get the accuracy
print("SVM Hyper Accuracy Score on Testing Data -> ",accuracy_score(predictions_SVM_Final, Test_Y)*100)
# Out:
# SVM Hyper Accuracy Score on Testing Data ->  87.07142857142857

# %%
print(classification_report(Test_Y, predictions_SVM_Final))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92      2093
#            1       0.82      0.63      0.71       707
#
#     accuracy                           0.87      2800
#    macro avg       0.85      0.79      0.81      2800
# weighted avg       0.87      0.87      0.86      2800
